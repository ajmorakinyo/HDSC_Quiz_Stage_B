# %% [markdown]
# #### Answer to Question 12

# %%
#Import Pandas
import pandas as pd

# %%
#Read the CSV File
energy_df = pd.read_csv('C:/Users/hp/Downloads/Hamoye/Stage B _ ML/Stage B Tag-Along Project/energydata_complete.csv')

# %%
#View the dataset in the file
energy_df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
#View the all statistical summaries, both mixed and numeric
energy_df.describe(include='all')
# Out:
#                        date    Appliances        lights            T1  \
# count                 19735  19735.000000  19735.000000  19735.000000
# unique                19735           NaN           NaN           NaN
# top     2016-01-11 17:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN     97.694958      3.801875     21.686571
# std                     NaN    102.524891      7.935988      1.606066
# min                     NaN     10.000000      0.000000     16.790000
# 25%                     NaN     50.000000      0.000000     20.760000
# 50%                     NaN     60.000000      0.000000     21.600000
# 75%                     NaN    100.000000      0.000000     22.600000
# max                     NaN   1080.000000     70.000000     26.260000
#
#                 RH_1            T2          RH_2            T3          RH_3  \
# ...

# %%
#Plot a simple linear regression using choice number of samples and desired random state
simple_lin_reg_df = energy_df[['T2','T6']].sample(15, random_state=2)

# %%
#Import seaborn and plot the graph of the relationship
import seaborn as sns
sns.regplot(x='T2',y='T6', data=simple_lin_reg_df)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='T6'>

# %%
#Import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
#Drop the date column
energy_df.drop('date', inplace=True, axis=1)

# %%
#Apply the MinMaxScaler
scaler = MinMaxScaler()
norm_df = pd.DataFrame(scaler.fit_transform(energy_df), columns=energy_df.columns)

# %%
#View changes
energy_df
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
#Segment features and target variables
features_df = norm_df.drop(columns=['T2','T6'])
heating_target = norm_df['T2']

# %%
#Split the dataset into training and testing dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df,heating_target,test_size=0.3,random_state=1)

# %%
#Import Linear Regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
#Fit the model to training set
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#Import R squared and solve for its value
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score,2)
# Out:
# 0.96

# %% [markdown]
# #### Answer to Question 13

# %%
#Re-read the CSV File
energy_df2 = pd.read_csv('C:/Users/hp/Downloads/Hamoye/Stage B _ ML/Stage B Tag-Along Project/energydata_complete.csv')

# %%
#View the dataset
energy_df2
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
#View all column headings
energy_df2.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
#Remove the date and lights 
features_df = energy_df2.drop(columns=['date','lights'])

# %%
#View features variable
features_df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
#Normalise the resultant dataset using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
norm_df = pd.DataFrame(scaler.fit_transform(features_df), columns=features_df.columns)

# %%
#View changes
norm_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
#Select target variable as Appliances
target_var = norm_df['Appliances']

# %%
#View target variable
target_var
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
#Split dataset into training and testing datasets using 70-30 train-test set split and random state of 42
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, target_var, test_size=0.3, random_state=42)

#Import Linear Regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
#Fit the model to the training set
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Obtain predictions
predicted_values = linear_model.predict(x_test)

# %%
#Solve for MAE in 2 decimal places
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error (y_test, predicted_values)
round(mae, 2)
# Out:
# 0.0

# %% [markdown]
# #### Answer to Question 14

# %%
#Calculate the Residual Sum of Squares to 2 decimal places
import numpy as np
rss = np.sum(np.square(y_test,predicted_values))
round(rss, 2)
# Out:
# 92.98

# %% [markdown]
# #### Answer to Question 15

# %%
#Calculate the Root Mean Squared Error in 3 decimal places
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse, 3)
# Out:
# 0.085

# %% [markdown]
# #### Answer to Question 16

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.21

# %% [markdown]
# #### Answer to Question 17

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(0.5)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features',col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0            T8        -3.465880e-17  3.727442e-11      0.000000
# 1            T9        -2.400616e-17 -7.888938e-11      0.000000
# 2         T_out        -2.071721e-17 -4.130263e-11      0.000000
# 3            T3        -2.046876e-17  9.639111e-11      0.000000
# 4          RH_7        -1.934070e-17 -6.315926e-12     -0.000000
# 5            T4        -9.428949e-18  1.041866e-11      0.000000
# 6          RH_3        -8.522392e-18  1.792104e-11      0.000000
# 7            T2        -7.012000e-18 -6.852254e-11      0.000000
# 8          RH_1        -3.704162e-18  6.081401e-11      0.000000
# 9        RH_out        -2.400763e-18 -4.077899e-12     -0.000000
# 10         RH_5        -1.809325e-18  9.609299e-13      0.000000
# 11    Windspeed        -1.013172e-18  8.322662e-12      0.000000
# 12         RH_6        -3.305882e-19  1.535779e-12     -0.000000
# ...

# %% [markdown]
# #### Answer to Question 18

# %%
#Use Ridge alpha value of 0.4
from sklearn.linear_model import Ridge
ridge_reg = Ridge(0.4)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.4)

# %%
#Check the effect of Ridge alpha value change on RMSE
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse, 3)
# Out:
# 0.085

# %% [markdown]
# #### Answer to Question 19

# %%
#Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it.
#How many of the features have non-zero feature weights?

from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features',col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0            T8        -3.465880e-17  2.982024e-11      0.000000
# 1            T9        -2.400616e-17 -6.311492e-11      0.000000
# 2         T_out        -2.071721e-17 -3.304453e-11      0.000000
# 3            T3        -2.046876e-17  7.711493e-11      0.000000
# 4          RH_7        -1.934070e-17 -5.052788e-12     -0.000000
# 5            T4        -9.428949e-18  8.335768e-12      0.000000
# 6          RH_3        -8.522392e-18  1.433693e-11      0.000000
# 7            T2        -7.012000e-18 -5.482147e-11      0.000000
# 8          RH_1        -3.704162e-18  4.865226e-11      0.000000
# 9        RH_out        -2.400763e-18 -3.262657e-12     -0.000000
# 10         RH_5        -1.809325e-18  7.687306e-13      0.000000
# 11    Windspeed        -1.013172e-18  6.658062e-12      0.000000
# 12         RH_6        -3.305882e-19  1.228654e-12     -0.000000
# ...

# %% [markdown]
# #### Answer to Question 20

# %%
#RMSE of New Lasso Regression
#Check the effect of Ridge alpha value change on RMSE
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,predicted_values))
round(rmse, 3)
# Out:
# 0.085
